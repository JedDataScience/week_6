# %% [markdown]
# # NBA Player Scouting Report for Mr. Rooney
# ## Using Data Science to Find the Right Players for the Wizards

# %% [markdown]
# ## Overview
#
# Mr. Rooney, this report uses advanced data analysis to group NBA players by their playing style not by their reputation or salary. By finding patterns in the numbers, we identified which players fit our team needs and which ones are overpriced for what they actually do on the court.

# %% [markdown]
# ## What We Did
#
#
# ### Step 1: Gathered the Data
# We collected every NBA player's statistics for the 2024-25 season—points scored, rebounds, minutes played, field goals, free throws, steals, blocks, etc.and then matched that with their 2025-26 salary information. We then cleaned the data by selecting features that would be good predictors of salary and performance like PTS, MP, FG%, 3P%, FT%, TRB, STL, and BLK.
#
# ### Step 2: Let the Computer Find Player Types
# Using a technique called "clustering," we let the computer group players based purely on how they play basketball. The computer doesn't know who's famous or who's highly paid it will just look at the stats and will group similar players together. For example:
# - High scorers with lots of minutes tend to cluster together
# - Rebounders and defenders cluster together
# - Bench players with limited minutes form their own group
# - ect...
#
# ### Step 3: Found the Right Number of Groups
# We tested different numbers of player groups 5 and 2. We started with **5 groups** because that captured the different player types well. Then we used two scientific methods to double-check:
#
# 1. **The Elbow Method:** This shows us when adding more groups stops being helpful (like when diminishing returns start)
# 2. **Silhouette Score:** This measures how well players fit into their assigned groups
#
#
# ### Step 4: Visualized the Clusters
# After grouping players, we created charts showing:
# - How players cluster based on Points and Rebounds
# - How salary overlays on top of these performance clusters
#
# This visual approach reveals the hidden gems—great players on cheap contracts.

# %% [markdown]
# ![](attachment:image.png)

# %% [markdown]
# ## How We Chose the Right Number of Groups
#
# Before making any player recommendations, we needed to determine how many groups (clusters) make sense. Too few groups oversimplifies things and too many creates confusion. We used two standard methods:
#
# - **The Elbow Method**
# This shows when adding more groups stops giving us better insights. The graph below plots "within-cluster variation" (basically, how tight the groups are). The "elbow" is where the line bends—that's the sweet spot.
# - **Silhouette Score**
# This measures how well players fit into their assigned groups. Higher scores mean better-defined clusters.

# %% [markdown]
# ## Visualizing the Player Groups
#
# Now that we've settled on our the number of clusters, let's see what these groups actually look like. The chart below shows players plotted by **Points Scored** and **Total Rebounds**. The color represents the salary, so darker colors are cheaper players and lighter colors are more expensive players. The shapes represent the cluster they are assigned.

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Our Recommendations

# %% [markdown]
# ### Good Choices - Elite performers for bargain prices
#
# These are the players we should pursue aggressively:
#
# | Player | Points | Rebounds | Salary | Cluster Insight |
# |--------|--------|----------|--------|-----------------|
# | **Victor Wembanyama** | 976 | 443 | $13.4M | In elite performance cluster, dominating in both scoring and rebounding. Tiny salary for this level of production. |
# | **Kon Knueppel** | 1,021 | 297 | $10.0M | High-scoring cluster member on rookie contract.
# | **Keyonte George** | 1,141 | 187 | $4.3M | Elite scoring cluster with bargain salary. |
#
# **Why These Three?**
#
# The combined cost of all three ($27.7M) is less than what many teams pay for one aging superstar. And we get championship-caliber production from multiple positions.

# %% [markdown]
# ### Not Good Choices - Avoid these expensive underperformers
#
#
# | Player | Points | Rebounds | Salary | Cluster Insight |
# |--------|--------|----------|--------|-----------------|
# | **Stephen Curry** | 1,061 | 138 | $59.6M | Still productive but extremely expensive. |
# | **Paul George** | 431 | 139 | $51.7M | Huge salary for limited output. |
# | **Anthony Davis** | 407 | 221 | $54.1M | Underwhelming production this season. |
#
# **The Problem:**
#
# When you hover over these players on the cluster chart, you see massive salaries attached to players who aren't in the elite performance clusters. While Curry, George, and Davis are household names, they're at career stages where injuries and age are reducing their effectiveness.
#
# These three veterans are earning a combined $165 million which is too expensive given their impact.

# %% [markdown]
# ### Could Work - Solid backup options
#
# If we can't land Wembanyama, Knueppel, or George, the clustering reveals reliable mid-tier alternatives—players who cluster near the middle on performance but still have reasonable salaries:
#
# | Player | Points | Rebounds | Salary | Cluster Role |
# |--------|--------|----------|--------|--------------|
# | **Jalen Duren** | 777 | 458 | $6.5M | In rebounding-specialist cluster. Elite rebounder at affordable price. |
# | **Cooper Flagg** | 999 | 321 | $13.8M | Mid-to-high performance cluster. Balanced two-way player. |
# | **Donovan Clingan** | 604 | 597 | $7.2M | Addresses our rebounding weakness cheaply. |
#
# These are young players on affordable contracts who contribute in great ways. Duren and Clingan address our rebounding weakness. Flagg provides versatility.
#
# Combined cost: $27.5M for three quality starters/rotation players.

# %% [markdown]
# ## Final Recommendations
#
# If we land our top three targets:
# - **Total Cost:** $27.7M
# - **Total Points:** 3,138
# - **Total Rebounds:** 927
# - **Upside:** All three are young and still improving
#
# ### The Bottom Line:
#
# Our clustering analysis shows exactly where the value is in today's NBA the young players in high-performance clusters who haven't hit expensive second contracts yet. That's how smart teams build on a budget.
#
# The Wizards' path to the playoffs isn't through expensive veterans. It's through identifying undervalued young talent before the rest of the league catches on.
#
# **The data speaks for itself—and it points directly to Wembanyama, Knueppel, and George.**
